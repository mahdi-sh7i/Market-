# %% [markdown]
# ## First part
# 1. import library
# 2. import dataset nad make dataframe
# 3. Extraction NYA
# 4. Remove the decimal
# 5. delete the Volume
# 6. reset_index
# 7. sort_values (data)
# 8. describe()

# %% [markdown]
# ### 1.import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.dates as mdates

# %% [markdown]
# ### 2. import dataset nad make dataframe

# %%
data = pd.read_csv ("/home/mahdi/A_fasl2/Download_dataset/Market/Market.csv")
data1 = data
data
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
df = pd.DataFrame (data)
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %% [markdown]
# ### 3. Extraction NYA

# %%
df1 = df[df["Index"] == "NYA"]
df1
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %% [markdown]
# ### 4. Remove the decimal

# %% [markdown]
# * Remove decimals
# * We use the **round** command to remove decimals
#
# https://stackoverflow.com/questions/37084812/how-to-remove-decimal-points-in-pandas

# %%
df2 = round (df1)
df2
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close  \
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
#              Volume
# 0      0.000000e+00
# 1      0.000000e+00
# 2      0.000000e+00
# 3      0.000000e+00
# ...

# %% [markdown]
# ### 5. delete the Volume

# %% [markdown]
# * We are asked to delete the **Volume** column
# * we are using **dropna** command to delete the **Volume** column

# %%
df3 = df2.drop(columns = "Volume")
df3
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13948 rows x 7 columns]

# %% [markdown]
# ### 6. reset_index

# %% [markdown]
# * Because we only removed NYA from the main dataframe. It is possible that the sequence of indexes has changed.For this reason, we reset the indexes once with the command **reset_index**

# %%
df3.reset_index(inplace=True)
df3
# Out:
#        index Index        Date     Open     High      Low    Close  Adj Close
# 0          0   NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...         ...      ...      ...      ...      ...        ...
# 13943  13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944  13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945  13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946  13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947  13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13948 rows x 8 columns]

# %% [markdown]
# ### 7. sort_values (data)

# %% [markdown]
# * because our dataset of type time series , We sort the dataset by **date**

# %%
df3.sort_values (by = ["Date"])
df3
# Out:
#        index Index        Date     Open     High      Low    Close  Adj Close
# 0          0   NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...         ...      ...      ...      ...      ...        ...
# 13943  13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944  13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945  13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946  13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947  13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13948 rows x 8 columns]

# %% [markdown]
# ### 8.describe()

# %% [markdown]
# * now the **describe** dataset

# %%
df3.describe()
# Out:
#               index          Open          High           Low         Close  \
# count  13948.000000  13947.000000  13946.000000  13945.000000  13944.000000
# mean    6973.500000   4452.144834   4469.313495   4434.260739   4453.026033
# std     4026.585112   4074.832916   4094.959937   4052.814928   4075.484621
# min        0.000000    348.000000    348.000000    348.000000    348.000000
# 25%     3486.750000    655.000000    655.000000    655.000000    655.000000
# 50%     6973.500000   2632.000000   2632.000000   2632.000000   2632.000000
# 75%    10460.250000   7339.500000   7376.500000   7278.000000   7339.750000
# max    13947.000000  16590.000000  16686.000000  16532.000000  16590.000000
#
#           Adj Close
# count  13938.000000
# mean    4455.093916
# std     4075.457549
# min      348.000000
# 25%      656.000000
# 50%     2633.000000
# 75%     7342.750000
# max    16590.000000

# %% [markdown]
# * using the command **isnall** count **Missing Values**

# %%
df3.isnull().sum()
# Out:
# index         0
# Index         0
# Date          0
# Open          1
# High          2
# Low           3
# Close         4
# Adj Close    10
# dtype: int64

# %% [markdown]
# ## second part
# 1. start drawing Feature and Noise detection
# 2. clean noise
# 3. clean missing value
# 4. reset_index
# 5. sort_values (data)

# %% [markdown]
# ### 1. start drawing Feature and Noise detection

# %% [markdown]
# * according to the above output number of missing values is little.for this reason , we can to be invisible but before that we check **noise**
# * for find noise **scatter** is best
# * start drawing Feature

# %% [markdown]
# #### A. Open vs Adj Close

# %%
# Open vs Adj Close
plt.scatter(df3["Open"] , df3["Adj Close"])
plt.xlabel("Open")
plt.ylabel("Adj Close")
plt.grid()
plt.show()

# %% [markdown]
# **Open vs Adj Close**
# * noise in up =  5500 < Adj Close < 6500
# * noise in up =  0 < Open < 1500
#
# * noise in down =  0 < Adj Close < 1500
# * noise in down =  5000 < Open < 6000

# %% [markdown]
# #### B. High vs Adj Close

# %%
# High vs Adj Close
plt.scatter(df3["High"] , df3["Adj Close"])
plt.xlabel("High")
plt.ylabel("Adj Close")
plt.grid()
plt.show()

# %% [markdown]
# **High vs Adj Close**
# * noise in up =  5500 < Adj Close < 6500
# * noise in up =  0 < High < 1500
#
# * noise in down =  0 < Adj Close < 1500
# * noise in down =  5000 < High < 6000

# %% [markdown]
# #### C. Low vs Adj Close

# %%
# Low vs Adj Close
plt.scatter(df3["Low"] , df3["Adj Close"])
plt.xlabel("Low")
plt.ylabel("Adj Close")
plt.grid()
plt.show()

# %% [markdown]
# **Low vs Adj Close**
# * noise in up =  5500 < Adj Close < 6500
# * noise in up =  0 < Low < 1500

# %% [markdown]
# #### D. Close vs Adj Close

# %%
# Close vs Adj Close
plt.scatter(df3["Close"] , df3["Adj Close"])
plt.xlabel("Close")
plt.ylabel("Adj Close")
plt.grid()
plt.show()

# %% [markdown]
# **Close vs Adj Close**
# * noise in up =  5500 < Adj Close < 6500
# * noise in up =  0 < Close < 1500

# %% [markdown]
# * We witness common noise in every four plot.
# For this reason on the first plot (name) we eliminate the noise
# (Since noise is common in every plot)

# %% [markdown]
# ### 2. clean noise

# %%
# Open vs Adj Close
plt.style.use('seaborn-v0_8-dark')
plt.scatter(df3["Open"] , df3["Adj Close"] , color = 'springgreen' )
plt.xlabel("Open")
plt.ylabel("Adj Close")
plt.grid()
plt.show()

# %% [markdown]
# **Open vs Adj Close**
# * *noise in up = niu*
# * *noise in dow = nid*
# * noise in up =  5500 < Adj Close < 6500
# * noise in up =  0 < Open < 1500
#
# * noise in down =  0 < Adj Close < 1500
# * noise in down =  5000 < Open < 6000

# %% [markdown]
# * We specify a noise limit inside the dataset , find noise id in dataset after that clean noise

# %%
niu = df3 [ ((df3["Adj Close"] > 5500) & (df3["Adj Close"] < 6500 ))  & ((df3["Open"] > 0) & (df3["Open"] < 1500))]
niu
# Out:
#      index Index       Date   Open   High    Low  Close  Adj Close
# 831    831   NYA  5/29/1969  612.0  612.0  612.0  612.0     6111.0

# %%
nid = df3 [ ((df3["Adj Close"] > 0) & (df3["Adj Close"] < 1500 ))  & ((df3["Open"] > 5000) & (df3["Open"] < 6000))]
nid
# Out:
#      index Index       Date    Open   High    Low  Close  Adj Close
# 852    852   NYA  6/30/1969  5722.0  572.0  572.0  572.0      572.0

# %% [markdown]
# * we find index noise now we clean them

# %%
df3.drop(index = [831,852] , inplace = True)
df3
# Out:
#        index Index        Date     Open     High      Low    Close  Adj Close
# 0          0   NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...         ...      ...      ...      ...      ...        ...
# 13943  13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944  13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945  13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946  13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947  13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13946 rows x 8 columns]

# %% [markdown]
# * First, we check (Open vs Adj Close)
# * ok , Cleared of noise

# %%
# Open vs Adj Close
plt.style.use('seaborn-v0_8-dark')
plt.scatter(df3["Open"] , df3["Adj Close"] , color = 'springgreen' )
plt.xlabel("Open")
plt.ylabel("Adj Close")
plt.grid()
plt.show()

# %% [markdown]
# * now we check all
# * in (High vs Adj Close) we find noise

# %%
x_vars = ["Open","High","Low","Close"]
y_vars = ["Adj Close"]
g = sns.PairGrid(df3, x_vars = x_vars , y_vars = y_vars)
g.map (sns.scatterplot)
g.add_legend();

# %% [markdown]
# * we want clean ((High vs Adj Close))

# %%
# Open vs Adj Close
plt.style.use('seaborn-v0_8-dark')
plt.scatter(df3["High"] , df3["Adj Close"] , color = 'springgreen' )
plt.xlabel("High")
plt.ylabel("Adj Close")
plt.grid()
plt.show()

# %%
nih = df3 [ ((df3["Adj Close"] > 0) & (df3["Adj Close"] < 1000 ))  & ((df3["High"] > 5950) & (df3["High"] < 6150))]
nih
# Out:
#      index Index       Date   Open    High    Low  Close  Adj Close
# 829    829   NYA  5/27/1969  612.0  6124.0  612.0  612.0      612.0
# 833    833   NYA   6/3/1969  607.0  6066.0  607.0  607.0      607.0

# %% [markdown]
# * There are two and we are clean them (829 , 833)

# %%
df3.drop(index = [829 , 833] , inplace = True)
df3
# Out:
#        index Index        Date     Open     High      Low    Close  Adj Close
# 0          0   NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...         ...      ...      ...      ...      ...        ...
# 13943  13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944  13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945  13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946  13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947  13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13944 rows x 8 columns]

# %% [markdown]
# * Again check plot

# %%
x_vars = ["Open","High","Low","Close"]
y_vars = ["Adj Close"]
g = sns.PairGrid(df3, x_vars = x_vars , y_vars = y_vars )
g.map (sns.scatterplot)
g.add_legend();

# %% [markdown]
# * very good , noise is clean
# * now we clean dataset from missing value

# %% [markdown]
# ### 3. clean missing value

# %% [markdown]
# * now we dropna dataset

# %%
df4 = df3.dropna()
df4
# Out:
#        index Index        Date     Open     High      Low    Close  Adj Close
# 0          0   NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...         ...      ...      ...      ...      ...        ...
# 13943  13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944  13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945  13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946  13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947  13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13928 rows x 8 columns]

# %% [markdown]
# * now check missing values in df4

# %%
df4.isnull().sum() # count Missing Values
# Out:
# index        0
# Index        0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# dtype: int64

# %% [markdown]
# * dataset is ok and dont have any missing value
# * Again reset dataset and sort values by date

# %% [markdown]
# ### 4. reset_index

# %%
df4.reset_index(inplace=True)
df4
# Out:
#        level_0  index Index        Date     Open     High      Low    Close  \
# 0            0      0   NYA  12/31/1965    529.0    529.0    529.0    529.0
# 1            1      1   NYA    1/3/1966    527.0    527.0    527.0    527.0
# 2            2      2   NYA    1/4/1966    528.0    528.0    528.0    528.0
# 3            3      3   NYA    1/5/1966    531.0    531.0    531.0    531.0
# 4            4      4   NYA    1/6/1966    532.0    532.0    532.0    532.0
# ...        ...    ...   ...         ...      ...      ...      ...      ...
# 13923    13943  13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0
# 13924    13944  13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0
# 13925    13945  13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0
# 13926    13946  13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0
# 13927    13947  13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0
#
#        Adj Close
# 0          529.0
# 1          527.0
# ...

# %% [markdown]
# ### 5. sort_values (data)

# %%
df4.sort_values (by = ["Date"])
df4
# Out:
#        level_0  index Index        Date     Open     High      Low    Close  \
# 0            0      0   NYA  12/31/1965    529.0    529.0    529.0    529.0
# 1            1      1   NYA    1/3/1966    527.0    527.0    527.0    527.0
# 2            2      2   NYA    1/4/1966    528.0    528.0    528.0    528.0
# 3            3      3   NYA    1/5/1966    531.0    531.0    531.0    531.0
# 4            4      4   NYA    1/6/1966    532.0    532.0    532.0    532.0
# ...        ...    ...   ...         ...      ...      ...      ...      ...
# 13923    13943  13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0
# 13924    13944  13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0
# 13925    13945  13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0
# 13926    13946  13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0
# 13927    13947  13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0
#
#        Adj Close
# 0          529.0
# 1          527.0
# ...

# %% [markdown]
# ## third part
# * now Dataframe is ready for analysis
# 1. New dataframe
# 2. chang type (data) for year
# 3. **A** >>  Date vs Adj Close (**part1**)
# 4. **A** >>  Date vs Adj Close (**part2**)
# 5. **A** >>  Date vs Adj Close (**part3**)
# 6. analyze month and year
# 7. analyze month
# 8. analyze year

# %% [markdown]
# # 1. New dataframe

# %% [markdown]
# * make new dataframe (df5)
# * i don't know what is (level_0) added to dataframe so i remove it.
# * and i want new dataframe for my analysis so i make (df5)

# %%
df5 = df4.drop(columns = "level_0")
df5
# Out:
#        index Index        Date     Open     High      Low    Close  Adj Close
# 0          0   NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...         ...      ...      ...      ...      ...        ...
# 13923  13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13924  13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13925  13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13926  13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13927  13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13928 rows x 8 columns]

# %% [markdown]
# * in this cell information about df5

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13928 entries, 0 to 13927
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      13928 non-null  int64
#  1   Index      13928 non-null  object
#  2   Date       13928 non-null  object
#  3   Open       13928 non-null  float64
#  4   High       13928 non-null  float64
#  5   Low        13928 non-null  float64
#  6   Close      13928 non-null  float64
#  7   Adj Close  13928 non-null  float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 870.6+ KB

# %% [markdown]
# # 2. chang type (data) for year

# %%
df6 = df5
df6
# Out:
#        index Index        Date     Open     High      Low    Close  Adj Close
# 0          0   NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...         ...      ...      ...      ...      ...        ...
# 13923  13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13924  13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13925  13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13926  13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13927  13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13928 rows x 8 columns]

# %% [markdown]
# * chang type (data) for year

# %%
df6 ['Date'] = pd.to_datetime(df6 ['Date'])
df6
# Out:
#        index Index       Date     Open     High      Low    Close  Adj Close
# 0          0   NYA 1965-12-31    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA 1966-01-03    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA 1966-01-04    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA 1966-01-05    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA 1966-01-06    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...        ...      ...      ...      ...      ...        ...
# 13923  13943   NYA 2021-05-24  16375.0  16509.0  16375.0  16465.0    16465.0
# 13924  13944   NYA 2021-05-25  16465.0  16526.0  16375.0  16390.0    16390.0
# 13925  13945   NYA 2021-05-26  16390.0  16466.0  16388.0  16452.0    16452.0
# 13926  13946   NYA 2021-05-27  16452.0  16546.0  16452.0  16532.0    16532.0
# 13927  13947   NYA 2021-05-28  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13928 rows x 8 columns]

# %% [markdown]
# * On the x axis, which is the data axis, this axis shows lot of years together as result  in showing years it cause confusion .
# For separating years change type of data in new data frame (df6).
# * As result  we have separated years.

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13928 entries, 0 to 13927
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      13928 non-null  int64
#  1   Index      13928 non-null  object
#  2   Date       13928 non-null  datetime64[ns]
#  3   Open       13928 non-null  float64
#  4   High       13928 non-null  float64
#  5   Low        13928 non-null  float64
#  6   Close      13928 non-null  float64
#  7   Adj Close  13928 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 870.6+ KB

# %% [markdown]
# * chang type (data) for year >> (Date)-13928 non-null  datetime64[ns]

# %% [markdown]
# # 3.(A) Date vs Adj Close (part1)

# %%
plt.figure (figsize = (18 , 6) , dpi = 120)
xd1=df6['Date']
ya1=df6['Adj Close']
plt.plot(xd1,ya1,c='c',lw = 0.8);

plt.title ('Date vs Adj Close', fontsize = 25)
plt.xlabel ("Date", fontsize = 20)
plt.ylabel ("Adj Close", fontsize = 20)
plt.grid()
plt.show ()

# %% [markdown]
# # 4.(A) Date vs Adj Close (part2)

# %% [markdown]
# * The plot of the second part is the same as the plot of the first part
#   - run in new page
#   - you can zoom in or out in this plot

# %%
pio.renderers.default='browser'

fig = make_subplots(specs=[[{"secondary_y":True}]])

fig.add_trace (
    go.Scatter(x=df5['Date'], y=df5['Adj Close'],name="losss"),secondary_y=False
              )
fig.update_layout(
    title_text = "Date vs Adj Close",
                 )
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="Adj Close", secondary_y=False)
fig.show()
# Out:
# /home/mahdi/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %% [markdown]
# **analyze part1 and part2**
# 1. This plot for 1966 - 2021 (year) , For the NYA index
# 2. Plot from the beginning of its starting year 1965 to 1990 , It is traded below the value of 2000
# 3. From 1990 to 2000 , The value of each share has tripled (6000).
# 4. Between the years 2000 and 2004, the value of shares decreased and It has dropped to about 4000
# 5. From 2004 to 2007, we are justified by the strong growth of the stock up to 10,000
# 6. And from 2007 to 2009, we see a rapid drop in the value of shares up to 4000 units
# 7. From 2010 to 2020, the stock had a relatively good growth and its value increased to 14,000
# 8. In 2020 to 2021, we are witnessing a severe shock and decrease in stock value after that The stock had a strong growth and reached up to 16,000 values

# %% [markdown]
# # 5.(A) Date vs Adj Close (part3)
#     -Candlestick

# %%
fig = go.Figure (data = [go.Candlestick(x = df6['Date'],
                open=df6['Open'],
                high=df6['High'],
                low=df6['Low'],
                close=df6['Close'] )])
fig.show()
# Out:
# /home/mahdi/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %% [markdown]
# **analyze part3**
# 1. Candlestick is used in this analysis
# 2. In 1998 to 2005 type of candle in the chart is different, this candle is just one line.
# In old financial data's in some years only and only there were one price and it was recorded so the order of data doesn't disturb.
# This case in data is visible, the price of four main columns are equal.

# %% [markdown]
# # 6. analyze month and year

# %% [markdown]
# **in this section i want to do two things**
# 1. analyze month
# 2. analyze year

# %% [markdown]
# * for do that i want new dataframe (df8)

# %%
df8 = df6
df8
# Out:
#        index Index       Date     Open     High      Low    Close  Adj Close
# 0          0   NYA 1965-12-31    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA 1966-01-03    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA 1966-01-04    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA 1966-01-05    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA 1966-01-06    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...        ...      ...      ...      ...      ...        ...
# 13923  13943   NYA 2021-05-24  16375.0  16509.0  16375.0  16465.0    16465.0
# 13924  13944   NYA 2021-05-25  16465.0  16526.0  16375.0  16390.0    16390.0
# 13925  13945   NYA 2021-05-26  16390.0  16466.0  16388.0  16452.0    16452.0
# 13926  13946   NYA 2021-05-27  16452.0  16546.0  16452.0  16532.0    16532.0
# 13927  13947   NYA 2021-05-28  16532.0  16589.0  16532.0  16556.0    16556.0
#
# [13928 rows x 8 columns]

# %% [markdown]
# * I extract the date and I separate the month and year

# %%
new = data1 ["Date"].str.split("/" , n = 2 , expand = True)
new
# Out:
#          0   1     2
# 0       12  31  1965
# 1        1   3  1966
# 2        1   4  1966
# 3        1   5  1966
# 4        1   6  1966
# ...     ..  ..   ...
# 112452   5  27  2021
# 112453   5  28  2021
# 112454   5  31  2021
# 112455   6   1  2021
# 112456   6   2  2021
#
# [112457 rows x 3 columns]

# %% [markdown]
# * add year to datafram

# %%
df8.insert(8 , "year" , new[2] , True)
df8
# Out:
#        index Index       Date     Open     High      Low    Close  Adj Close  \
# 0          0   NYA 1965-12-31    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA 1966-01-03    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA 1966-01-04    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA 1966-01-05    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA 1966-01-06    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...        ...      ...      ...      ...      ...        ...
# 13923  13943   NYA 2021-05-24  16375.0  16509.0  16375.0  16465.0    16465.0
# 13924  13944   NYA 2021-05-25  16465.0  16526.0  16375.0  16390.0    16390.0
# 13925  13945   NYA 2021-05-26  16390.0  16466.0  16388.0  16452.0    16452.0
# 13926  13946   NYA 2021-05-27  16452.0  16546.0  16452.0  16532.0    16532.0
# 13927  13947   NYA 2021-05-28  16532.0  16589.0  16532.0  16556.0    16556.0
#
#        year
# 0      1965
# 1      1966
# ...

# %% [markdown]
# * for analyze month I have to check the month every year
# * so i Merge year and month

# %%
df8['Y_month']  = new [0].astype(str) + '/' + new [2]
df8
# Out:
#        index Index       Date     Open     High      Low    Close  Adj Close  \
# 0          0   NYA 1965-12-31    529.0    529.0    529.0    529.0      529.0
# 1          1   NYA 1966-01-03    527.0    527.0    527.0    527.0      527.0
# 2          2   NYA 1966-01-04    528.0    528.0    528.0    528.0      528.0
# 3          3   NYA 1966-01-05    531.0    531.0    531.0    531.0      531.0
# 4          4   NYA 1966-01-06    532.0    532.0    532.0    532.0      532.0
# ...      ...   ...        ...      ...      ...      ...      ...        ...
# 13923  13943   NYA 2021-05-24  16375.0  16509.0  16375.0  16465.0    16465.0
# 13924  13944   NYA 2021-05-25  16465.0  16526.0  16375.0  16390.0    16390.0
# 13925  13945   NYA 2021-05-26  16390.0  16466.0  16388.0  16452.0    16452.0
# 13926  13946   NYA 2021-05-27  16452.0  16546.0  16452.0  16532.0    16532.0
# 13927  13947   NYA 2021-05-28  16532.0  16589.0  16532.0  16556.0    16556.0
#
#        year  Y_month
# 0      1965  12/1965
# ...

# %% [markdown]
# * now we make two datafrom for groupby years and month

# %%
Datamonth = df8.groupby (pd.Grouper (key="Y_month") , as_index = False).mean(numeric_only=True)
Datamonth
# Out:
#      Y_month    index          Open          High           Low         Close  \
# 0    12/1965      0.0    529.000000    529.000000    529.000000    529.000000
# 1     1/1966     11.0    534.619048    534.619048    534.619048    534.619048
# 2     2/1966     31.0    532.263158    532.263158    532.263158    532.263158
# 3     3/1966     52.0    510.565217    510.565217    510.565217    510.565217
# 4     4/1966     73.5    524.450000    524.450000    524.450000    524.450000
# ..       ...      ...           ...           ...           ...           ...
# 660  12/2020  13854.5  14799.136364  14878.818182  14701.000000  14794.500000
# 661   1/2021  13875.0  15189.263158  15295.052632  15104.473684  15227.789474
# 662   2/2021  13894.0  15446.157895  15562.368421  15344.578947  15464.842105
# 663   3/2021  13915.0  15965.000000  16039.391304  15918.043478  15995.130435
# 664   4/2021  13937.0  16365.619048  16452.952381  16284.190476  16374.190476
#
#         Adj Close
# ...

# %%
Datayear = df8.groupby (pd.Grouper (key="year") , as_index = False).mean(numeric_only=True)
Datayear
# Out:
#     year         index          Open          High           Low  \
# 0   1965      0.000000    529.000000    529.000000    529.000000
# 1   1966    128.817460    487.646825    487.646825    487.646825
# 2   1967    389.195219    540.760956    540.760956    540.760956
# 3   1968    630.172566    585.703540    585.703540    585.703540
# 4   1969    872.860000    571.928000    571.940000    571.928000
# 5   1970   1126.500000    483.507874    483.507874    483.507874
# 6   1971   1380.000000    578.454545    578.454545    578.454545
# 7   1972   1632.000000    643.346614    643.346614    643.346614
# 8   1973   1883.500000    596.123016    596.123016    596.123016
# 9   1974   2136.000000    452.272727    452.272727    452.272727
# 10  1975   2389.000000    494.426877    494.426877    494.426877
# 11  1976   2642.000000    580.280632    580.280632    580.280632
# 12  1977   2894.500000    562.123016    562.123016    562.123016
# ...

# %% [markdown]
# * now we are redy for ploy

# %% [markdown]
# # 7. analyze month

# %% [markdown]
# * plot **A** for month

# %%
plt.figure (figsize = (18 , 6) , dpi = 120)
xd1=Datamonth['Y_month']
ya1=Datamonth['Adj Close']
plt.plot(xd1,ya1,c='c',lw = 0.8);

plt.title ('month vs Adj Close', fontsize = 25)
plt.xlabel ("Y_month", fontsize = 20)
plt.ylabel ("Adj Close", fontsize = 20)
plt.grid()
plt.show ()

# %% [markdown]
# * this plot is like plot part1
# * and year is not ok so i ues other plot

# %% [markdown]
# * plot **B** for month

# %%
pio.renderers.default='browser'

fig = make_subplots(specs=[[{"secondary_y":True}]])

fig.add_trace (
    go.Scatter(x=Datamonth['Y_month'], y=Datamonth['Adj Close'],name="losss"),secondary_y=False
              )
fig.update_layout(
    title_text = "month vs Adj Close",
                 )
fig.update_xaxes(title_text="month")
fig.update_yaxes(title_text="Adj Close", secondary_y=False)
fig.show()

# %% [markdown]
# 1. this one is better than last one
# 2. you can zoom in or out
# 3. open in new page
# 4. Monthly plot has less  details than daily plot

# %% [markdown]
# * plot **c** for month

# %%
fig = go.Figure (data = [go.Candlestick(x = df6['Date'],
                open=df6['Open'],
                high=df6['High'],
                low=df6['Low'],
                close=df6['Close'] )])
fig.show()
# Out:
# /home/mahdi/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %% [markdown]
# * this is so good you can analyze candel each month

# %% [markdown]
# # 8. analyze year

# %% [markdown]
# * plot **A** for month

# %%
plt.figure (figsize = (18 , 6) , dpi = 120)
xd1=Datayear['year']
ya1=Datayear['Adj Close']
plt.plot(xd1,ya1,c='c',lw = 0.8);

plt.title ('year vs Adj Close', fontsize = 25)
plt.xlabel ("year", fontsize = 20)
plt.ylabel ("Adj Close", fontsize = 20)
plt.xticks(rotation = 90)
plt.grid()
plt.show ()

# %% [markdown]
# * in this plot The price is separated by year
# * This plot shows the generalities well but does not include the details
# * for analyze year is very good
# * this analyze is like last ones (part 1)

# %% [markdown]
# * plot **B** for year

# %%
pio.renderers.default='browser'

fig = make_subplots(specs=[[{"secondary_y":True}]])

fig.add_trace (
    go.Scatter(x=Datayear['year'], y=Datayear['Adj Close'],name="losss"),secondary_y=False
              )
fig.update_layout(
    title_text = "year vs Adj Close",
                 )
fig.update_xaxes(title_text="year")
fig.update_yaxes(title_text="Adj Close", secondary_y=False)
fig.show()

# %% [markdown]
# * is like last ones
# * is open in new page

# %%
* plot **c** for year

# %%
fig = go.Figure (data = [go.Candlestick(x = Datayear['year'],
                open=Datayear['Open'],
                high=Datayear['High'],
                low=Datayear['Low'],
                close=Datayear['Close'] )])
fig.show()

# %% [markdown]
# * The ratio of supply to demand has been close to each other in different years, that's why candles don't have a big shadow. And they are displayed as one line.

# %% [markdown]
# # **end**
